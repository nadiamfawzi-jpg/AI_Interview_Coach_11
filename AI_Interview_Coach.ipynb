# %% [markdown]
# # AI Interview Coach

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 33.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 6.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Step 1: Import

# %%
import os
os.listdir("/content")
# Out:
# ['.config',
#  '.ipynb_checkpoints',
#  'sample_data',
#  'AI Interview Coach 11',
#  '__pycache__']

# %%
# !find /content -name "video_utils.py"
# Out:
# /content/sample_data/video_utils.py
# /content/AI Interview Coach 11/video_utils.py

# %%
# %cd /content/AI Interview Coach 11
# Out:
# /content/AI Interview Coach 11

# %%
import pandas as pd

from interview_utils import load_questions, select_question, check_answer
from video_utils import annotate_video, annotate_pose
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## Step 2: Load and inspect the questions

# %%
questions_df = load_questions("questions.csv")
questions_df.head()
# Out:
#              Field                                           Question  \
# 0     Data Science  Tell me about a data science project you worke...
# 1     Data Science                  How do you handle missing values?
# 2     Data Science  What is the difference between classification ...
# 3  Human Resources                            Tell me about yourself.
# 4  Human Resources         How would you handle an employee conflict?
#
#                                         Ideal_Answer  \
# 0  I explain the problem the data source the clea...
# 1  I first inspect how much data is missing and w...
# 2  Classification predicts a category such as chu...
# 3  I briefly introduce my education and relevant ...
# 4  I would listen to both employees separately re...
#
#                                             Keywords
# 0      problem|data|cleaning|model|evaluation|result
# 1  inspect|remove|imputation|mean|median|mode|val...
# 2  category|continuous|classification|regression|...
# ...

# %%
questions_df["Field"].value_counts()
# Out:
# Field
# Data Science            3
# Human Resources         3
# Software Development    3
# Marketing               3
# Finance                 3
# Name: count, dtype: int64

# %% [markdown]
# ## Step 3: Choose a question
#
# Change the field and question number. The first question is number `0`.

# %%
field = "Human Resources"
question_number = 0

selected = select_question(questions_df, field, question_number)
selected[["Field", "Question"]]
# Out:
# Field               Human Resources
# Question    Tell me about yourself.
# Name: 0, dtype: object

# %% [markdown]
# ## Step 4: Write and check the answer
#
# This is a literal keyword checklist, not a trained NLP model or a quality score.

# %%
answer = "I have experience in HR and I enjoy communication and supporting employees."

# %%
answer_result = check_answer(answer, selected["Keywords"])

print("Question:", selected["Question"])
print("Word count:", answer_result["word_count"])
print("Included ideas:", answer_result["matched_words"])
print("Ideas to consider:", answer_result["missing_words"])

answer_result["results_df"]
# Out:
# Question: Tell me about yourself.
# Word count: 12
# Included ideas: ['experience', 'communication']
# Ideas to consider: ['education', 'strengths', 'confidentiality', 'role']
#           Key idea Included
# 0        education       No
# 1       experience      Yes
# 2        strengths       No
# 3    communication      Yes
# 4  confidentiality       No
# 5             role       No

# %%
print("Sample answer for self-review:")
print(selected["Ideal_Answer"])
# Out:
# Sample answer for self-review:
# I briefly introduce my education and relevant HR experience then highlight strengths such as organisation communication and confidentiality and explain why I am interested in this role.

# %% [markdown]
# ## Step 5: Annotate an uploaded interview video
#
# Upload an MP4 file to the same folder and update `video_path`. Generic YOLO object detection only marks objects it recognises. It does not evaluate delivery.

# %%
video_path = "interview_video.mp4"
output_path = "annotated_interview.mp4"

annotate_video(video_path, output_path)
# Out:
# ...
# 'annotated_interview.mp4'

# %% [markdown]
# ## Optional: Pose visualisation
#
# The pose model draws body keypoints. The notebook does not convert them into a confidence, nervousness, or gesture-quality score.

# %%
pose_output_path = "pose_interview.mp4"
annotate_pose(video_path, pose_output_path)
# Out:
# ...
# 'pose_interview.mp4'
